# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
filepath = "../data/Final Categorization Data.csv"

df = pd.read_csv(filepath).sort_values(by=['SPD_DTOT'])

# %%
df['Origin Destination Province'] = df['Origin Province'] + df['Destination Province']
df['Origin Destination Region'] = df['Origin Province'] + df['Destination Region']
df['Origin Destination New Region'] = df['Origin Province'] + df['New Regions']
df['Origin Destination Metro Area'] = df['Origin Province'] + df['Destination Metro Area']

# %%
fig, axes = plt.subplots(nrows = 2, ncols=3, figsize = (20,15))

sns.histplot(ax=axes[0,0], x = 'Total Bins (20)', data=df, hue="Main Reason", multiple='stack')
sns.histplot(ax=axes[0,1], x = 'Transport Bins (20)', data=df, hue="Main Reason", multiple='stack')
sns.histplot(ax=axes[0,2], x = 'Food Bins (20)', data=df, hue="Main Reason", multiple='stack')
sns.histplot(ax=axes[1,0], x = 'Shopping Bins (20)', data=df, hue="Main Reason", multiple='stack')
sns.histplot(ax=axes[1,1], x = 'Activities Bins (20)', data=df, hue="Main Reason", multiple='stack')
sns.histplot(ax=axes[1,2], x = 'Accomodations Bins (20)', data=df, hue="Main Reason", multiple='stack')
# Out:
# <Axes: xlabel='Accomodations Bins (20)', ylabel='Count'>

# %%
fig, axes = plt.subplots(nrows = 2, ncols=3, figsize = (20,15))

sns.histplot(ax=axes[0,0], x = 'Total Bins (20)', data=df, hue="Quarter", multiple='stack')
sns.histplot(ax=axes[0,1], x = 'Transport Bins (20)', data=df, hue="Quarter", multiple='stack')
sns.histplot(ax=axes[0,2], x = 'Food Bins (20)', data=df, hue="Quarter", multiple='stack')
sns.histplot(ax=axes[1,0], x = 'Shopping Bins (20)', data=df, hue="Quarter", multiple='stack')
sns.histplot(ax=axes[1,1], x = 'Activities Bins (20)', data=df, hue="Quarter", multiple='stack')
sns.histplot(ax=axes[1,2], x = 'Accomodations Bins (20)', data=df, hue="Quarter", multiple='stack')
# Out:
# <Axes: xlabel='Accomodations Bins (20)', ylabel='Count'>

# %%
fig, axes = plt.subplots(nrows = 2, ncols=3, figsize = (20,15))

sns.histplot(ax=axes[0,0], x = 'Total Bins (20)', data=df, hue="Age Range", multiple='stack')
sns.histplot(ax=axes[0,1], x = 'Transport Bins (20)', data=df, hue="Age Range", multiple='stack')
sns.histplot(ax=axes[0,2], x = 'Food Bins (20)', data=df, hue="Age Range", multiple='stack')
sns.histplot(ax=axes[1,0], x = 'Shopping Bins (20)', data=df, hue="Age Range", multiple='stack')
sns.histplot(ax=axes[1,1], x = 'Activities Bins (20)', data=df, hue="Age Range", multiple='stack')
sns.histplot(ax=axes[1,2], x = 'Accomodations Bins (20)', data=df, hue="Age Range", multiple='stack')
# Out:
# <Axes: xlabel='Accomodations Bins (20)', ylabel='Count'>

# %%
fig, axes = plt.subplots(nrows = 2, ncols=3, sharey=True, figsize = (20,15))

sns.barplot(ax=axes[0,0], x ='Total Bins (20)', y='DURATION', data=df, fill=True)
sns.barplot(ax=axes[0,1], x ='Transport Bins (20)', y='DURATION', data=df, fill=True)
sns.barplot(ax=axes[0,2], x ='Food Bins (20)', y='DURATION', data=df, fill=True)
sns.barplot(ax=axes[1,0], x ='Shopping Bins (20)', y='DURATION', data=df, fill=True)
sns.barplot(ax=axes[1,1], x ='Activities Bins (20)', y='DURATION', data=df, fill=True)
sns.barplot(ax=axes[1,2], x ='Accomodations Bins (20)', y='DURATION', data=df, fill=True)
# Out:
# <Axes: xlabel='Accomodations Bins (20)', ylabel='DURATION'>

# %%
fig, axes = plt.subplots(nrows = 2, ncols=3, sharey=True, figsize = (20,15))

sns.barplot(ax=axes[0,0], x ='Total Bins (20)', y='GNCQ06A', data=df, fill=True)
sns.barplot(ax=axes[0,1], x ='Transport Bins (20)', y='GNCQ06A', data=df, fill=True)
sns.barplot(ax=axes[0,2], x ='Food Bins (20)', y='GNCQ06A', data=df, fill=True)
sns.barplot(ax=axes[1,0], x ='Shopping Bins (20)', y='GNCQ06A', data=df, fill=True)
sns.barplot(ax=axes[1,1], x ='Activities Bins (20)', y='GNCQ06A', data=df, fill=True)
sns.barplot(ax=axes[1,2], x ='Accomodations Bins (20)', y='GNCQ06A', data=df, fill=True)
# Out:
# <Axes: xlabel='Accomodations Bins (20)', ylabel='GNCQ06A'>

# %%
fig, axes = plt.subplots(nrows = 2, ncols=3, sharey=True, figsize = (20,15))

sns.barplot(ax=axes[0,0], x ='Total Bins (20)', y='GNCQ06B', data=df, fill=True)
sns.barplot(ax=axes[0,1], x ='Transport Bins (20)', y='GNCQ06B', data=df, fill=True)
sns.barplot(ax=axes[0,2], x ='Food Bins (20)', y='GNCQ06B', data=df, fill=True)
sns.barplot(ax=axes[1,0], x ='Shopping Bins (20)', y='GNCQ06B', data=df, fill=True)
sns.barplot(ax=axes[1,1], x ='Activities Bins (20)', y='GNCQ06B', data=df, fill=True)
sns.barplot(ax=axes[1,2], x ='Accomodations Bins (20)', y='GNCQ06B', data=df, fill=True)
# Out:
# <Axes: xlabel='Accomodations Bins (20)', ylabel='GNCQ06B'>

# %%
from pandas import factorize
labels, categories = factorize(df['Origin Province'])
df['labels'] = labels
print(abs(df['SPD_DTOT'].corr(df['labels'])))
print(abs(df['Total Spending for transport'].corr(df['labels'])))
print(abs(df['Total Spending for food/bevs'].corr(df['labels'])))
print(abs(df['Total spending on shopping'].corr(df['labels'])))
print(abs(df['Total spending for activities/entertainment'].corr(df['labels'])))
print(abs(df['SPD_D06'].corr(df['labels'])))
# Out:
# 0.0371665761264435
# 0.0291022286306424
# 0.030319352149816126
# 0.05155048769728574
# 0.0034602090700940804
# 0.007705697180602559

# %%
labels, categories = factorize(df['Destination Province'])
df['labels'] = labels
print(abs(df['SPD_DTOT'].corr(df['labels'])))
print(abs(df['Total Spending for transport'].corr(df['labels'])))
print(abs(df['Total Spending for food/bevs'].corr(df['labels'])))
print(abs(df['Total spending on shopping'].corr(df['labels'])))
print(abs(df['Total spending for activities/entertainment'].corr(df['labels'])))
print(abs(df['SPD_D06'].corr(df['labels'])))
# Out:
# 0.02619929789742455
# 0.02025578528989475
# 0.015106568303574918
# 0.021199066975160934
# 0.006050088346991635
# 0.0097897118169791

# %%
labels, categories = factorize(df['New Regions'])
df['labels'] = labels
print(abs(df['SPD_DTOT'].corr(df['labels'])))
print(abs(df['Total Spending for transport'].corr(df['labels'])))
print(abs(df['Total Spending for food/bevs'].corr(df['labels'])))
print(abs(df['Total spending on shopping'].corr(df['labels'])))
print(abs(df['Total spending for activities/entertainment'].corr(df['labels'])))
print(abs(df['SPD_D06'].corr(df['labels'])))
# Out:
# 0.04573743109632349
# 0.025368492972191882
# 0.04231938463542682
# 0.014183344514215851
# 0.043224017533556626
# 0.026993423347805183

# %%
labels, categories = factorize(df['Destination Region'])
df['labels'] = labels
print(abs(df['SPD_DTOT'].corr(df['labels'])))
print(abs(df['Total Spending for transport'].corr(df['labels'])))
print(abs(df['Total Spending for food/bevs'].corr(df['labels'])))
print(abs(df['Total spending on shopping'].corr(df['labels'])))
print(abs(df['Total spending for activities/entertainment'].corr(df['labels'])))
print(abs(df['SPD_D06'].corr(df['labels'])))
# Out:
# 0.02279534322175502
# 0.0026671538691042194
# 0.021588464097033022
# 0.0005455744032580484
# 0.026181046512861253
# 0.010428018584107458

# %%
labels, categories = factorize(df['Destination Metro Area'])
df['labels'] = labels
print(abs(df['SPD_DTOT'].corr(df['labels'])))
print(abs(df['Total Spending for transport'].corr(df['labels'])))
print(abs(df['Total Spending for food/bevs'].corr(df['labels'])))
print(abs(df['Total spending on shopping'].corr(df['labels'])))
print(abs(df['Total spending for activities/entertainment'].corr(df['labels'])))
print(abs(df['SPD_D06'].corr(df['labels'])))
# Out:
# 0.05989697892946298
# 0.04660355040037438
# 0.07482401988935145
# 0.0705270448572736
# 0.020747614077781352
# 0.011834928883318023

# %%
from pandas import factorize
labels, categories = factorize(df['Origin Destination Province'])
df['labels'] = labels
print(abs(df['SPD_DTOT'].corr(df['labels'])))
print(abs(df['Total Spending for transport'].corr(df['labels'])))
print(abs(df['Total Spending for food/bevs'].corr(df['labels'])))
print(abs(df['Total spending on shopping'].corr(df['labels'])))
print(abs(df['Total spending for activities/entertainment'].corr(df['labels'])))
print(abs(df['SPD_D06'].corr(df['labels'])))
# Out:
# 0.3916850991972335
# 0.3186675969988537
# 0.35945116809054833
# 0.12311602525791068
# 0.19175974403151086
# 0.18738200363467258

# %%
from pandas import factorize
labels, categories = factorize(df['Origin Destination Region'])
df['labels'] = labels
print(abs(df['SPD_DTOT'].corr(df['labels'])))
print(abs(df['Total Spending for transport'].corr(df['labels'])))
print(abs(df['Total Spending for food/bevs'].corr(df['labels'])))
print(abs(df['Total spending on shopping'].corr(df['labels'])))
print(abs(df['Total spending for activities/entertainment'].corr(df['labels'])))
print(abs(df['SPD_D06'].corr(df['labels'])))
# Out:
# 0.3995564725004453
# 0.3140932607419788
# 0.363583486177526
# 0.12039003055442105
# 0.22380657988762187
# 0.198234739816904

# %%
from pandas import factorize
labels, categories = factorize(df['Origin Destination New Region'])
df['labels'] = labels
print(abs(df['SPD_DTOT'].corr(df['labels'])))
print(abs(df['Total Spending for transport'].corr(df['labels'])))
print(abs(df['Total Spending for food/bevs'].corr(df['labels'])))
print(abs(df['Total spending on shopping'].corr(df['labels'])))
print(abs(df['Total spending for activities/entertainment'].corr(df['labels'])))
print(abs(df['SPD_D06'].corr(df['labels'])))
# Out:
# 0.37631919959646715
# 0.2979715859058727
# 0.3440766410103619
# 0.12241052584032938
# 0.21604371093718147
# 0.17367077864165406

# %%
from pandas import factorize
labels, categories = factorize(df['Origin Destination Metro Area'])
df['labels'] = labels
print(abs(df['SPD_DTOT'].corr(df['labels'])))
print(abs(df['Total Spending for transport'].corr(df['labels'])))
print(abs(df['Total Spending for food/bevs'].corr(df['labels'])))
print(abs(df['Total spending on shopping'].corr(df['labels'])))
print(abs(df['Total spending for activities/entertainment'].corr(df['labels'])))
print(abs(df['SPD_D06'].corr(df['labels'])))
# Out:
# 0.300811423149224
# 0.24624393314823392
# 0.2902818603268215
# 0.12492740638041352
# 0.13173203866336528
# 0.12122732362404674

# %%
fig, axes = plt.subplots(nrows = 5, ncols=7, sharex=True, sharey=True, figsize = (20,15))

sns.histplot(ax=axes[0,0], x = 'Total Bins (20)', data=df, hue="Visit Friends & Family", legend=False, multiple='stack')
sns.histplot(ax=axes[0,1], x = 'Total Bins (20)', data=df, hue="Shopping", legend=False, multiple='stack')
sns.histplot(ax=axes[0,2], x = 'Total Bins (20)', data=df, hue="Sightseeing", legend=False, multiple='stack')
sns.histplot(ax=axes[0,3], x = 'Total Bins (20)', data=df, hue="Museum/Art Gallery", legend=False, multiple='stack')
sns.histplot(ax=axes[0,4], x = 'Total Bins (20)', data=df, hue="Historic site", legend=False, multiple='stack')
sns.histplot(ax=axes[0,5], x = 'Total Bins (20)', data=df, hue="Zoo/Aquarium", legend=False, multiple='stack')
sns.histplot(ax=axes[0,6], x = 'Total Bins (20)', data=df, hue="Sprts Event as Spectator", legend=False, multiple='stack')

sns.histplot(ax=axes[1,0], x = 'Total Bins (20)', data=df, hue="Festival or Fair", legend=False, multiple='stack')
sns.histplot(ax=axes[1,1], x = 'Total Bins (20)', data=df, hue="Performance such as Play or Concert", legend=False, multiple='stack')
sns.histplot(ax=axes[1,2], x = 'Total Bins (20)', data=df, hue="Casino", legend=False, multiple='stack')
sns.histplot(ax=axes[1,3], x = 'Total Bins (20)', data=df, hue="Theme/Amusement Park", legend=False, multiple='stack')
sns.histplot(ax=axes[1,4], x = 'Total Bins (20)', data=df, hue="Aboriginal Event", legend=False, multiple='stack')
sns.histplot(ax=axes[1,5], x = 'Total Bins (20)', data=df, hue="Movies", legend=False, multiple='stack')
sns.histplot(ax=axes[1,6], x = 'Total Bins (20)', data=df, hue="Restaurant/Bar/Club", legend=False, multiple='stack')

sns.histplot(ax=axes[2,0], x = 'Total Bins (20)', data=df, hue="Wildife Viewing/Bird Watching", legend=False, multiple='stack')
sns.histplot(ax=axes[2,1], x = 'Total Bins (20)', data=df, hue="National/Provincial/Nature Park", legend=False, multiple='stack')
sns.histplot(ax=axes[2,2], x = 'Total Bins (20)', data=df, hue="Medical/Health Treatment", legend=False, multiple='stack')
sns.histplot(ax=axes[2,3], x = 'Total Bins (20)', data=df, hue="Business Meeting/Conference/Seminar", legend=False, multiple='stack')
sns.histplot(ax=axes[2,4], x = 'Total Bins (20)', data=df, hue="All-Terrain Vehicle", legend=False, multiple='stack')
sns.histplot(ax=axes[2,5], x = 'Total Bins (20)', data=df, hue="Boating", legend=False, multiple='stack')
sns.histplot(ax=axes[2,6], x = 'Total Bins (20)', data=df, hue="Canoeing/Kayaking", legend=False, multiple='stack')

sns.histplot(ax=axes[3,0], x = 'Total Bins (20)', data=df, hue="Camping", legend=False, multiple='stack')
sns.histplot(ax=axes[3,1], x = 'Total Bins (20)', data=df, hue="Hiking/Backpacking", legend=False, multiple='stack')
sns.histplot(ax=axes[3,2], x = 'Total Bins (20)', data=df, hue="Fishing", legend=False, multiple='stack')
sns.histplot(ax=axes[3,3], x = 'Total Bins (20)', data=df, hue="Beach", legend=False, multiple='stack')
sns.histplot(ax=axes[3,4], x = 'Total Bins (20)', data=df, hue="Hunting", legend=False, multiple='stack')
sns.histplot(ax=axes[3,5], x = 'Total Bins (20)', data=df, hue="Golfing", legend=False, multiple='stack')
sns.histplot(ax=axes[3,6], x = 'Total Bins (20)', data=df, hue="Cycling", legend=False, multiple='stack')

sns.histplot(ax=axes[4,0], x = 'Total Bins (20)', data=df, hue="Snowmobiling", legend=False, multiple='stack')
sns.histplot(ax=axes[4,1], x = 'Total Bins (20)', data=df, hue="Downhill Skiing/Snowboarding", legend=False, multiple='stack')
sns.histplot(ax=axes[4,2], x = 'Total Bins (20)', data=df, hue="Cross-country Skiing/Snowshoeing", legend=False, multiple='stack')
sns.histplot(ax=axes[4,3], x = 'Total Bins (20)', data=df, hue="Play Sports", legend=False, multiple='stack')
sns.histplot(ax=axes[4,4], x = 'Total Bins (20)', data=df, hue="Other Activity", legend=False, multiple='stack')
sns.histplot(ax=axes[4,5], x = 'Total Bins (20)', data=df, hue="No Activities", legend=True, multiple='stack')
# Out:
# <Axes: xlabel='Total Bins (20)', ylabel='Count'>

# %%
fig, axes = plt.subplots(nrows = 5, ncols=7, sharex=True, sharey=True, figsize = (20,15))

sns.histplot(ax=axes[0,0], x = 'Transport Bins (20)', data=df, hue="Visit Friends & Family", legend=False, multiple='stack')
sns.histplot(ax=axes[0,1], x = 'Transport Bins (20)', data=df, hue="Shopping", legend=False, multiple='stack')
sns.histplot(ax=axes[0,2], x = 'Transport Bins (20)', data=df, hue="Sightseeing", legend=False, multiple='stack')
sns.histplot(ax=axes[0,3], x = 'Transport Bins (20)', data=df, hue="Museum/Art Gallery", legend=False, multiple='stack')
sns.histplot(ax=axes[0,4], x = 'Transport Bins (20)', data=df, hue="Historic site", legend=False, multiple='stack')
sns.histplot(ax=axes[0,5], x = 'Transport Bins (20)', data=df, hue="Zoo/Aquarium", legend=False, multiple='stack')
sns.histplot(ax=axes[0,6], x = 'Transport Bins (20)', data=df, hue="Sprts Event as Spectator", legend=False, multiple='stack')

sns.histplot(ax=axes[1,0], x = 'Transport Bins (20)', data=df, hue="Festival or Fair", legend=False, multiple='stack')
sns.histplot(ax=axes[1,1], x = 'Transport Bins (20)', data=df, hue="Performance such as Play or Concert", legend=False, multiple='stack')
sns.histplot(ax=axes[1,2], x = 'Transport Bins (20)', data=df, hue="Casino", legend=False, multiple='stack')
sns.histplot(ax=axes[1,3], x = 'Transport Bins (20)', data=df, hue="Theme/Amusement Park", legend=False, multiple='stack')
sns.histplot(ax=axes[1,4], x = 'Transport Bins (20)', data=df, hue="Aboriginal Event", legend=False, multiple='stack')
sns.histplot(ax=axes[1,5], x = 'Transport Bins (20)', data=df, hue="Movies", legend=False, multiple='stack')
sns.histplot(ax=axes[1,6], x = 'Transport Bins (20)', data=df, hue="Restaurant/Bar/Club", legend=False, multiple='stack')

sns.histplot(ax=axes[2,0], x = 'Transport Bins (20)', data=df, hue="Wildife Viewing/Bird Watching", legend=False, multiple='stack')
sns.histplot(ax=axes[2,1], x = 'Transport Bins (20)', data=df, hue="National/Provincial/Nature Park", legend=False, multiple='stack')
sns.histplot(ax=axes[2,2], x = 'Transport Bins (20)', data=df, hue="Medical/Health Treatment", legend=False, multiple='stack')
sns.histplot(ax=axes[2,3], x = 'Transport Bins (20)', data=df, hue="Business Meeting/Conference/Seminar", legend=False, multiple='stack')
sns.histplot(ax=axes[2,4], x = 'Transport Bins (20)', data=df, hue="All-Terrain Vehicle", legend=False, multiple='stack')
sns.histplot(ax=axes[2,5], x = 'Transport Bins (20)', data=df, hue="Boating", legend=False, multiple='stack')
sns.histplot(ax=axes[2,6], x = 'Transport Bins (20)', data=df, hue="Canoeing/Kayaking", legend=False, multiple='stack')

sns.histplot(ax=axes[3,0], x = 'Transport Bins (20)', data=df, hue="Camping", legend=False, multiple='stack')
sns.histplot(ax=axes[3,1], x = 'Transport Bins (20)', data=df, hue="Hiking/Backpacking", legend=False, multiple='stack')
sns.histplot(ax=axes[3,2], x = 'Transport Bins (20)', data=df, hue="Fishing", legend=False, multiple='stack')
sns.histplot(ax=axes[3,3], x = 'Transport Bins (20)', data=df, hue="Beach", legend=False, multiple='stack')
sns.histplot(ax=axes[3,4], x = 'Transport Bins (20)', data=df, hue="Hunting", legend=False, multiple='stack')
sns.histplot(ax=axes[3,5], x = 'Transport Bins (20)', data=df, hue="Golfing", legend=False, multiple='stack')
sns.histplot(ax=axes[3,6], x = 'Transport Bins (20)', data=df, hue="Cycling", legend=False, multiple='stack')

sns.histplot(ax=axes[4,0], x = 'Transport Bins (20)', data=df, hue="Snowmobiling", legend=False, multiple='stack')
sns.histplot(ax=axes[4,1], x = 'Transport Bins (20)', data=df, hue="Downhill Skiing/Snowboarding", legend=False, multiple='stack')
sns.histplot(ax=axes[4,2], x = 'Transport Bins (20)', data=df, hue="Cross-country Skiing/Snowshoeing", legend=False, multiple='stack')
sns.histplot(ax=axes[4,3], x = 'Transport Bins (20)', data=df, hue="Play Sports", legend=False, multiple='stack')
sns.histplot(ax=axes[4,4], x = 'Transport Bins (20)', data=df, hue="Other Activity", legend=False, multiple='stack')
sns.histplot(ax=axes[4,5], x = 'Transport Bins (20)', data=df, hue="No Activities", legend=True, multiple='stack')
# Out:
# <Axes: xlabel='Transport Bins (20)', ylabel='Count'>

# %%
fig, axes = plt.subplots(nrows = 5, ncols=7, sharex=True, sharey=True, figsize = (20,15))

sns.histplot(ax=axes[0,0], x = 'Food Bins (20)', data=df, hue="Visit Friends & Family", legend=False, multiple='stack')
sns.histplot(ax=axes[0,1], x = 'Food Bins (20)', data=df, hue="Shopping", legend=False, multiple='stack')
sns.histplot(ax=axes[0,2], x = 'Food Bins (20)', data=df, hue="Sightseeing", legend=False, multiple='stack')
sns.histplot(ax=axes[0,3], x = 'Food Bins (20)', data=df, hue="Museum/Art Gallery", legend=False, multiple='stack')
sns.histplot(ax=axes[0,4], x = 'Food Bins (20)', data=df, hue="Historic site", legend=False, multiple='stack')
sns.histplot(ax=axes[0,5], x = 'Food Bins (20)', data=df, hue="Zoo/Aquarium", legend=False, multiple='stack')
sns.histplot(ax=axes[0,6], x = 'Food Bins (20)', data=df, hue="Sprts Event as Spectator", legend=False, multiple='stack')

sns.histplot(ax=axes[1,0], x = 'Food Bins (20)', data=df, hue="Festival or Fair", legend=False, multiple='stack')
sns.histplot(ax=axes[1,1], x = 'Food Bins (20)', data=df, hue="Performance such as Play or Concert", legend=False, multiple='stack')
sns.histplot(ax=axes[1,2], x = 'Food Bins (20)', data=df, hue="Casino", legend=False, multiple='stack')
sns.histplot(ax=axes[1,3], x = 'Food Bins (20)', data=df, hue="Theme/Amusement Park", legend=False, multiple='stack')
sns.histplot(ax=axes[1,4], x = 'Food Bins (20)', data=df, hue="Aboriginal Event", legend=False, multiple='stack')
sns.histplot(ax=axes[1,5], x = 'Food Bins (20)', data=df, hue="Movies", legend=False, multiple='stack')
sns.histplot(ax=axes[1,6], x = 'Food Bins (20)', data=df, hue="Restaurant/Bar/Club", legend=False, multiple='stack')

sns.histplot(ax=axes[2,0], x = 'Food Bins (20)', data=df, hue="Wildife Viewing/Bird Watching", legend=False, multiple='stack')
sns.histplot(ax=axes[2,1], x = 'Food Bins (20)', data=df, hue="National/Provincial/Nature Park", legend=False, multiple='stack')
sns.histplot(ax=axes[2,2], x = 'Food Bins (20)', data=df, hue="Medical/Health Treatment", legend=False, multiple='stack')
sns.histplot(ax=axes[2,3], x = 'Food Bins (20)', data=df, hue="Business Meeting/Conference/Seminar", legend=False, multiple='stack')
sns.histplot(ax=axes[2,4], x = 'Food Bins (20)', data=df, hue="All-Terrain Vehicle", legend=False, multiple='stack')
sns.histplot(ax=axes[2,5], x = 'Food Bins (20)', data=df, hue="Boating", legend=False, multiple='stack')
sns.histplot(ax=axes[2,6], x = 'Food Bins (20)', data=df, hue="Canoeing/Kayaking", legend=False, multiple='stack')

sns.histplot(ax=axes[3,0], x = 'Food Bins (20)', data=df, hue="Camping", legend=False, multiple='stack')
sns.histplot(ax=axes[3,1], x = 'Food Bins (20)', data=df, hue="Hiking/Backpacking", legend=False, multiple='stack')
sns.histplot(ax=axes[3,2], x = 'Food Bins (20)', data=df, hue="Fishing", legend=False, multiple='stack')
sns.histplot(ax=axes[3,3], x = 'Food Bins (20)', data=df, hue="Beach", legend=False, multiple='stack')
sns.histplot(ax=axes[3,4], x = 'Food Bins (20)', data=df, hue="Hunting", legend=False, multiple='stack')
sns.histplot(ax=axes[3,5], x = 'Food Bins (20)', data=df, hue="Golfing", legend=False, multiple='stack')
sns.histplot(ax=axes[3,6], x = 'Food Bins (20)', data=df, hue="Cycling", legend=False, multiple='stack')

sns.histplot(ax=axes[4,0], x = 'Food Bins (20)', data=df, hue="Snowmobiling", legend=False, multiple='stack')
sns.histplot(ax=axes[4,1], x = 'Food Bins (20)', data=df, hue="Downhill Skiing/Snowboarding", legend=False, multiple='stack')
sns.histplot(ax=axes[4,2], x = 'Food Bins (20)', data=df, hue="Cross-country Skiing/Snowshoeing", legend=False, multiple='stack')
sns.histplot(ax=axes[4,3], x = 'Food Bins (20)', data=df, hue="Play Sports", legend=False, multiple='stack')
sns.histplot(ax=axes[4,4], x = 'Food Bins (20)', data=df, hue="Other Activity", legend=False, multiple='stack')
sns.histplot(ax=axes[4,5], x = 'Food Bins (20)', data=df, hue="No Activities", legend=True, multiple='stack')
# Out:
# <Axes: xlabel='Food Bins (20)', ylabel='Count'>

# %%
fig, axes = plt.subplots(nrows = 5, ncols=7, sharex=True, sharey=True, figsize = (20,15))

sns.histplot(ax=axes[0,0], x = 'Shopping Bins (20)', data=df, hue="Visit Friends & Family", legend=False, multiple='stack')
sns.histplot(ax=axes[0,1], x = 'Shopping Bins (20)', data=df, hue="Shopping", legend=False, multiple='stack')
sns.histplot(ax=axes[0,2], x = 'Shopping Bins (20)', data=df, hue="Sightseeing", legend=False, multiple='stack')
sns.histplot(ax=axes[0,3], x = 'Shopping Bins (20)', data=df, hue="Museum/Art Gallery", legend=False, multiple='stack')
sns.histplot(ax=axes[0,4], x = 'Shopping Bins (20)', data=df, hue="Historic site", legend=False, multiple='stack')
sns.histplot(ax=axes[0,5], x = 'Shopping Bins (20)', data=df, hue="Zoo/Aquarium", legend=False, multiple='stack')
sns.histplot(ax=axes[0,6], x = 'Shopping Bins (20)', data=df, hue="Sprts Event as Spectator", legend=False, multiple='stack')

sns.histplot(ax=axes[1,0], x = 'Shopping Bins (20)', data=df, hue="Festival or Fair", legend=False, multiple='stack')
sns.histplot(ax=axes[1,1], x = 'Shopping Bins (20)', data=df, hue="Performance such as Play or Concert", legend=False, multiple='stack')
sns.histplot(ax=axes[1,2], x = 'Shopping Bins (20)', data=df, hue="Casino", legend=False, multiple='stack')
sns.histplot(ax=axes[1,3], x = 'Shopping Bins (20)', data=df, hue="Theme/Amusement Park", legend=False, multiple='stack')
sns.histplot(ax=axes[1,4], x = 'Shopping Bins (20)', data=df, hue="Aboriginal Event", legend=False, multiple='stack')
sns.histplot(ax=axes[1,5], x = 'Shopping Bins (20)', data=df, hue="Movies", legend=False, multiple='stack')
sns.histplot(ax=axes[1,6], x = 'Shopping Bins (20)', data=df, hue="Restaurant/Bar/Club", legend=False, multiple='stack')

sns.histplot(ax=axes[2,0], x = 'Shopping Bins (20)', data=df, hue="Wildife Viewing/Bird Watching", legend=False, multiple='stack')
sns.histplot(ax=axes[2,1], x = 'Shopping Bins (20)', data=df, hue="National/Provincial/Nature Park", legend=False, multiple='stack')
sns.histplot(ax=axes[2,2], x = 'Shopping Bins (20)', data=df, hue="Medical/Health Treatment", legend=False, multiple='stack')
sns.histplot(ax=axes[2,3], x = 'Shopping Bins (20)', data=df, hue="Business Meeting/Conference/Seminar", legend=False, multiple='stack')
sns.histplot(ax=axes[2,4], x = 'Shopping Bins (20)', data=df, hue="All-Terrain Vehicle", legend=False, multiple='stack')
sns.histplot(ax=axes[2,5], x = 'Shopping Bins (20)', data=df, hue="Boating", legend=False, multiple='stack')
sns.histplot(ax=axes[2,6], x = 'Shopping Bins (20)', data=df, hue="Canoeing/Kayaking", legend=False, multiple='stack')

sns.histplot(ax=axes[3,0], x = 'Shopping Bins (20)', data=df, hue="Camping", legend=False, multiple='stack')
sns.histplot(ax=axes[3,1], x = 'Shopping Bins (20)', data=df, hue="Hiking/Backpacking", legend=False, multiple='stack')
sns.histplot(ax=axes[3,2], x = 'Shopping Bins (20)', data=df, hue="Fishing", legend=False, multiple='stack')
sns.histplot(ax=axes[3,3], x = 'Shopping Bins (20)', data=df, hue="Beach", legend=False, multiple='stack')
sns.histplot(ax=axes[3,4], x = 'Shopping Bins (20)', data=df, hue="Hunting", legend=False, multiple='stack')
sns.histplot(ax=axes[3,5], x = 'Shopping Bins (20)', data=df, hue="Golfing", legend=False, multiple='stack')
sns.histplot(ax=axes[3,6], x = 'Shopping Bins (20)', data=df, hue="Cycling", legend=False, multiple='stack')

sns.histplot(ax=axes[4,0], x = 'Shopping Bins (20)', data=df, hue="Snowmobiling", legend=False, multiple='stack')
sns.histplot(ax=axes[4,1], x = 'Shopping Bins (20)', data=df, hue="Downhill Skiing/Snowboarding", legend=False, multiple='stack')
sns.histplot(ax=axes[4,2], x = 'Shopping Bins (20)', data=df, hue="Cross-country Skiing/Snowshoeing", legend=False, multiple='stack')
sns.histplot(ax=axes[4,3], x = 'Shopping Bins (20)', data=df, hue="Play Sports", legend=False, multiple='stack')
sns.histplot(ax=axes[4,4], x = 'Shopping Bins (20)', data=df, hue="Other Activity", legend=False, multiple='stack')
sns.histplot(ax=axes[4,5], x = 'Shopping Bins (20)', data=df, hue="No Activities", legend=True, multiple='stack')
# Out:
# <Axes: xlabel='Shopping Bins (20)', ylabel='Count'>

# %%
fig, axes = plt.subplots(nrows = 5, ncols=7, sharex=True, sharey=True, figsize = (20,15))

sns.histplot(ax=axes[0,0], x = 'Activities Bins (20)', data=df, hue="Visit Friends & Family", legend=False, multiple='stack')
sns.histplot(ax=axes[0,1], x = 'Activities Bins (20)', data=df, hue="Shopping", legend=False, multiple='stack')
sns.histplot(ax=axes[0,2], x = 'Activities Bins (20)', data=df, hue="Sightseeing", legend=False, multiple='stack')
sns.histplot(ax=axes[0,3], x = 'Activities Bins (20)', data=df, hue="Museum/Art Gallery", legend=False, multiple='stack')
sns.histplot(ax=axes[0,4], x = 'Activities Bins (20)', data=df, hue="Historic site", legend=False, multiple='stack')
sns.histplot(ax=axes[0,5], x = 'Activities Bins (20)', data=df, hue="Zoo/Aquarium", legend=False, multiple='stack')
sns.histplot(ax=axes[0,6], x = 'Activities Bins (20)', data=df, hue="Sprts Event as Spectator", legend=False, multiple='stack')

sns.histplot(ax=axes[1,0], x = 'Activities Bins (20)', data=df, hue="Festival or Fair", legend=False, multiple='stack')
sns.histplot(ax=axes[1,1], x = 'Activities Bins (20)', data=df, hue="Performance such as Play or Concert", legend=False, multiple='stack')
sns.histplot(ax=axes[1,2], x = 'Activities Bins (20)', data=df, hue="Casino", legend=False, multiple='stack')
sns.histplot(ax=axes[1,3], x = 'Activities Bins (20)', data=df, hue="Theme/Amusement Park", legend=False, multiple='stack')
sns.histplot(ax=axes[1,4], x = 'Activities Bins (20)', data=df, hue="Aboriginal Event", legend=False, multiple='stack')
sns.histplot(ax=axes[1,5], x = 'Activities Bins (20)', data=df, hue="Movies", legend=False, multiple='stack')
sns.histplot(ax=axes[1,6], x = 'Activities Bins (20)', data=df, hue="Restaurant/Bar/Club", legend=False, multiple='stack')

sns.histplot(ax=axes[2,0], x = 'Activities Bins (20)', data=df, hue="Wildife Viewing/Bird Watching", legend=False, multiple='stack')
sns.histplot(ax=axes[2,1], x = 'Activities Bins (20)', data=df, hue="National/Provincial/Nature Park", legend=False, multiple='stack')
sns.histplot(ax=axes[2,2], x = 'Activities Bins (20)', data=df, hue="Medical/Health Treatment", legend=False, multiple='stack')
sns.histplot(ax=axes[2,3], x = 'Activities Bins (20)', data=df, hue="Business Meeting/Conference/Seminar", legend=False, multiple='stack')
sns.histplot(ax=axes[2,4], x = 'Activities Bins (20)', data=df, hue="All-Terrain Vehicle", legend=False, multiple='stack')
sns.histplot(ax=axes[2,5], x = 'Activities Bins (20)', data=df, hue="Boating", legend=False, multiple='stack')
sns.histplot(ax=axes[2,6], x = 'Activities Bins (20)', data=df, hue="Canoeing/Kayaking", legend=False, multiple='stack')

sns.histplot(ax=axes[3,0], x = 'Activities Bins (20)', data=df, hue="Camping", legend=False, multiple='stack')
sns.histplot(ax=axes[3,1], x = 'Activities Bins (20)', data=df, hue="Hiking/Backpacking", legend=False, multiple='stack')
sns.histplot(ax=axes[3,2], x = 'Activities Bins (20)', data=df, hue="Fishing", legend=False, multiple='stack')
sns.histplot(ax=axes[3,3], x = 'Activities Bins (20)', data=df, hue="Beach", legend=False, multiple='stack')
sns.histplot(ax=axes[3,4], x = 'Activities Bins (20)', data=df, hue="Hunting", legend=False, multiple='stack')
sns.histplot(ax=axes[3,5], x = 'Activities Bins (20)', data=df, hue="Golfing", legend=False, multiple='stack')
sns.histplot(ax=axes[3,6], x = 'Activities Bins (20)', data=df, hue="Cycling", legend=False, multiple='stack')

sns.histplot(ax=axes[4,0], x = 'Activities Bins (20)', data=df, hue="Snowmobiling", legend=False, multiple='stack')
sns.histplot(ax=axes[4,1], x = 'Activities Bins (20)', data=df, hue="Downhill Skiing/Snowboarding", legend=False, multiple='stack')
sns.histplot(ax=axes[4,2], x = 'Activities Bins (20)', data=df, hue="Cross-country Skiing/Snowshoeing", legend=False, multiple='stack')
sns.histplot(ax=axes[4,3], x = 'Activities Bins (20)', data=df, hue="Play Sports", legend=False, multiple='stack')
sns.histplot(ax=axes[4,4], x = 'Activities Bins (20)', data=df, hue="Other Activity", legend=False, multiple='stack')
sns.histplot(ax=axes[4,5], x = 'Activities Bins (20)', data=df, hue="No Activities", legend=True, multiple='stack')
# Out:
# <Axes: xlabel='Activities Bins (20)', ylabel='Count'>

# %%
fig, axes = plt.subplots(nrows = 5, ncols=7, sharex=True, sharey=True, figsize = (20,15))

sns.histplot(ax=axes[0,0], x = 'Accomodations Bins (20)', data=df, hue="Visit Friends & Family", legend=False, multiple='stack')
sns.histplot(ax=axes[0,1], x = 'Accomodations Bins (20)', data=df, hue="Shopping", legend=False, multiple='stack')
sns.histplot(ax=axes[0,2], x = 'Accomodations Bins (20)', data=df, hue="Sightseeing", legend=False, multiple='stack')
sns.histplot(ax=axes[0,3], x = 'Accomodations Bins (20)', data=df, hue="Museum/Art Gallery", legend=False, multiple='stack')
sns.histplot(ax=axes[0,4], x = 'Accomodations Bins (20)', data=df, hue="Historic site", legend=False, multiple='stack')
sns.histplot(ax=axes[0,5], x = 'Accomodations Bins (20)', data=df, hue="Zoo/Aquarium", legend=False, multiple='stack')
sns.histplot(ax=axes[0,6], x = 'Accomodations Bins (20)', data=df, hue="Sprts Event as Spectator", legend=False, multiple='stack')

sns.histplot(ax=axes[1,0], x = 'Accomodations Bins (20)', data=df, hue="Festival or Fair", legend=False, multiple='stack')
sns.histplot(ax=axes[1,1], x = 'Accomodations Bins (20)', data=df, hue="Performance such as Play or Concert", legend=False, multiple='stack')
sns.histplot(ax=axes[1,2], x = 'Accomodations Bins (20)', data=df, hue="Casino", legend=False, multiple='stack')
sns.histplot(ax=axes[1,3], x = 'Accomodations Bins (20)', data=df, hue="Theme/Amusement Park", legend=False, multiple='stack')
sns.histplot(ax=axes[1,4], x = 'Accomodations Bins (20)', data=df, hue="Aboriginal Event", legend=False, multiple='stack')
sns.histplot(ax=axes[1,5], x = 'Accomodations Bins (20)', data=df, hue="Movies", legend=False, multiple='stack')
sns.histplot(ax=axes[1,6], x = 'Accomodations Bins (20)', data=df, hue="Restaurant/Bar/Club", legend=False, multiple='stack')

sns.histplot(ax=axes[2,0], x = 'Accomodations Bins (20)', data=df, hue="Wildife Viewing/Bird Watching", legend=False, multiple='stack')
sns.histplot(ax=axes[2,1], x = 'Accomodations Bins (20)', data=df, hue="National/Provincial/Nature Park", legend=False, multiple='stack')
sns.histplot(ax=axes[2,2], x = 'Accomodations Bins (20)', data=df, hue="Medical/Health Treatment", legend=False, multiple='stack')
sns.histplot(ax=axes[2,3], x = 'Accomodations Bins (20)', data=df, hue="Business Meeting/Conference/Seminar", legend=False, multiple='stack')
sns.histplot(ax=axes[2,4], x = 'Accomodations Bins (20)', data=df, hue="All-Terrain Vehicle", legend=False, multiple='stack')
sns.histplot(ax=axes[2,5], x = 'Accomodations Bins (20)', data=df, hue="Boating", legend=False, multiple='stack')
sns.histplot(ax=axes[2,6], x = 'Accomodations Bins (20)', data=df, hue="Canoeing/Kayaking", legend=False, multiple='stack')

sns.histplot(ax=axes[3,0], x = 'Accomodations Bins (20)', data=df, hue="Camping", legend=False, multiple='stack')
sns.histplot(ax=axes[3,1], x = 'Accomodations Bins (20)', data=df, hue="Hiking/Backpacking", legend=False, multiple='stack')
sns.histplot(ax=axes[3,2], x = 'Accomodations Bins (20)', data=df, hue="Fishing", legend=False, multiple='stack')
sns.histplot(ax=axes[3,3], x = 'Accomodations Bins (20)', data=df, hue="Beach", legend=False, multiple='stack')
sns.histplot(ax=axes[3,4], x = 'Accomodations Bins (20)', data=df, hue="Hunting", legend=False, multiple='stack')
sns.histplot(ax=axes[3,5], x = 'Accomodations Bins (20)', data=df, hue="Golfing", legend=False, multiple='stack')
sns.histplot(ax=axes[3,6], x = 'Accomodations Bins (20)', data=df, hue="Cycling", legend=False, multiple='stack')

sns.histplot(ax=axes[4,0], x = 'Accomodations Bins (20)', data=df, hue="Snowmobiling", legend=False, multiple='stack')
sns.histplot(ax=axes[4,1], x = 'Accomodations Bins (20)', data=df, hue="Downhill Skiing/Snowboarding", legend=False, multiple='stack')
sns.histplot(ax=axes[4,2], x = 'Accomodations Bins (20)', data=df, hue="Cross-country Skiing/Snowshoeing", legend=False, multiple='stack')
sns.histplot(ax=axes[4,3], x = 'Accomodations Bins (20)', data=df, hue="Play Sports", legend=False, multiple='stack')
sns.histplot(ax=axes[4,4], x = 'Accomodations Bins (20)', data=df, hue="Other Activity", legend=False, multiple='stack')
sns.histplot(ax=axes[4,5], x = 'Accomodations Bins (20)', data=df, hue="No Activities", legend=True, multiple='stack')
# Out:
# <Axes: xlabel='Accomodations Bins (20)', ylabel='Count'>
